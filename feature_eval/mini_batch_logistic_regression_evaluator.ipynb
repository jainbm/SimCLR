# %% [markdown]
# <a href="https://colab.research.google.com/github/sthalles/SimCLR/blob/simclr-refactor/feature_eval/mini_batch_logistic_regression_evaluator.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import torch
import sys
import numpy as np
import os
import yaml
import matplotlib.pyplot as plt
import torchvision

# %%
# !pip install gdown
# Out:
# Collecting gdown
#   Downloading gdown-3.12.2.tar.gz (8.2 kB)
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#     Preparing wheel metadata: started
#     Preparing wheel metadata: finished with status 'done'
# Requirement already satisfied: six in c:\users\jainb1\appdata\local\continuum\anaconda3\envs\simclr\lib\site-packages (from gdown) (1.15.0)
# Requirement already satisfied: requests[socks] in c:\users\jainb1\appdata\local\continuum\anaconda3\envs\simclr\lib\site-packages (from gdown) (2.24.0)
# Collecting filelock
#   Downloading filelock-3.0.12-py3-none-any.whl (7.6 kB)
# Requirement already satisfied: tqdm in c:\users\jainb1\appdata\local\continuum\anaconda3\envs\simclr\lib\site-packages (from gdown) (4.50.2)
# Requirement already satisfied: idna<3,>=2.5 in c:\users\jainb1\appdata\local\continuum\anaconda3\envs\simclr\lib\site-packages (from requests[socks]->gdown) (2.10)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\jainb1\appdata\local\continuum\anaconda3\envs\simclr\lib\site-packages (from requests[socks]->gdown) (2020.6.20)
# Requirement already satisfied: chardet<4,>=3.0.2 in c:\users\jainb1\appdata\local\continuum\anaconda3\envs\simclr\lib\site-packages (from requests[socks]->gdown) (3.0.4)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in c:\users\jainb1\appdata\local\continuum\anaconda3\envs\simclr\lib\site-packages (from requests[socks]->gdown) (1.25.11)
# Requirement already satisfied: PySocks!=1.5.7,>=1.5.6; extra == "socks" in c:\users\jainb1\appdata\local\continuum\anaconda3\envs\simclr\lib\site-packages (from requests[socks]->gdown) (1.7.1)
# Building wheels for collected packages: gdown
#   Building wheel for gdown (PEP 517): started
#   Building wheel for gdown (PEP 517): finished with status 'done'
#   Created wheel for gdown: filename=gdown-3.12.2-py3-none-any.whl size=9681 sha256=4854ece904d628827a034d750cf854efcf1a00aa112ed41ad4958b6e16570695
#   Stored in directory: c:\users\jainb1\appdata\local\pip\cache\wheels\ba\e0\7e\726e872a53f7358b4b96a9975b04e98113b005cd8609a63abc
# Successfully built gdown
# Installing collected packages: filelock, gdown
# Successfully installed filelock-3.0.12 gdown-3.12.2

# %%
from torch.utils.data import DataLoader
import torchvision.transforms as transforms
from torchvision import datasets
import resnet_simclr

# %%
device = 'cuda' if torch.cuda.is_available() else 'cpu'
print("Using device:", device)
# Out:
# Using device: cuda

# %%
def get_stl10_data_loaders(download, shuffle=False, batch_size=256):
  train_dataset = datasets.STL10('./data', split='train', download=download,
                                  transform=transforms.ToTensor())

  train_loader = DataLoader(train_dataset, batch_size=batch_size,
                            num_workers=0, drop_last=False, shuffle=shuffle)
  
  test_dataset = datasets.STL10('./data', split='test', download=download,
                                  transform=transforms.ToTensor())

  test_loader = DataLoader(test_dataset, batch_size=2*batch_size,
                            num_workers=10, drop_last=False, shuffle=shuffle)
  return train_loader, test_loader

def get_cifar10_data_loaders(download, shuffle=False, batch_size=256):
  train_dataset = datasets.CIFAR10('./data', train=True, download=download,
                                  transform=transforms.ToTensor())

  train_loader = DataLoader(train_dataset, batch_size=batch_size,
                            num_workers=0, drop_last=False, shuffle=shuffle)
  
  test_dataset = datasets.CIFAR10('./data', train=False, download=download,
                                  transform=transforms.ToTensor())

  test_loader = DataLoader(test_dataset, batch_size=2*batch_size,
                            num_workers=10, drop_last=False, shuffle=shuffle)
  return train_loader, test_loader

# %%
with open(os.path.join('./config.yml')) as file:
  config = yaml.load(file)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-5-e0de09c9d379> in <module>
# ----> 1 with open(os.path.join('./config.yml')) as file:
#       2   config = yaml.load(file)
#
# FileNotFoundError: [Errno 2] No such file or directory: './config.yml'

# %%
model = resnet_simclr.ResNetSimCLR(base_model='mobilev2', out_dim=128).to(device)
checkpoint = torch.load('checkpoint_0100.pth.tar', map_location=device)
state_dict = checkpoint['state_dict']




# for k in list(state_dict.keys()):

#   if k.startswith('backbone.'):
#     if k.startswith('backbone') and not k.startswith('backbone.fc'):
#       # remove prefix
#       state_dict[k[len("backbone."):]] = state_dict[k]
#   del state_dict[k]
# Out:
# mobilev2 Backbone Selected

# %%
# print(state_dict['backbone.classifier.1.2.bias'].shape)
# print('**************************************************************')
# print(model.state_dict().keys())
model.load_state_dict(state_dict)

print(model)
# Out:
# ResNetSimCLR(
#   (backbone): MobileNetV2(
#     (features): Sequential(
#       (0): ConvBNReLU(
#         (0): Conv2d(3, 32, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#         (1): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (2): ReLU6(inplace=True)
#       )
#       (1): InvertedResidual(
#         (conv): Sequential(
#           (0): ConvBNReLU(
#             (0): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=32, bias=False)
#             (1): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): ReLU6(inplace=True)
#           )
#           (1): Conv2d(32, 16, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (2): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#       )
#       (2): InvertedResidual(
#         (conv): Sequential(
#           (0): ConvBNReLU(
#             (0): Conv2d(16, 96, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(96, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): ReLU6(inplace=True)
#           )
#           (1): ConvBNReLU(
#             (0): Conv2d(96, 96, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), groups=96, bias=False)
#             (1): BatchNorm2d(96, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): ReLU6(inplace=True)
#           )
#           (2): Conv2d(96, 24, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (3): BatchNorm2d(24, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#       )
#       (3): InvertedResidual(
#         (conv): Sequential(
#           (0): ConvBNReLU(
#             (0): Conv2d(24, 144, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(144, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): ReLU6(inplace=True)
#           )
#           (1): ConvBNReLU(
#             (0): Conv2d(144, 144, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=144, bias=False)
#             (1): BatchNorm2d(144, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): ReLU6(inplace=True)
#           )
#           (2): Conv2d(144, 24, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (3): BatchNorm2d(24, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#       )
#       (4): InvertedResidual(
#         (conv): Sequential(
#           (0): ConvBNReLU(
#             (0): Conv2d(24, 144, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(144, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): ReLU6(inplace=True)
#           )
#           (1): ConvBNReLU(
#             (0): Conv2d(144, 144, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), groups=144, bias=False)
#             (1): BatchNorm2d(144, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): ReLU6(inplace=True)
#           )
#           (2): Conv2d(144, 32, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (3): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#       )
#       (5): InvertedResidual(
#         (conv): Sequential(
#           (0): ConvBNReLU(
#             (0): Conv2d(32, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): ReLU6(inplace=True)
#           )
#           (1): ConvBNReLU(
#             (0): Conv2d(192, 192, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=192, bias=False)
#             (1): BatchNorm2d(192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): ReLU6(inplace=True)
#           )
#           (2): Conv2d(192, 32, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (3): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#       )
#       (6): InvertedResidual(
#         (conv): Sequential(
#           (0): ConvBNReLU(
#             (0): Conv2d(32, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): ReLU6(inplace=True)
#           )
#           (1): ConvBNReLU(
#             (0): Conv2d(192, 192, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=192, bias=False)
#             (1): BatchNorm2d(192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): ReLU6(inplace=True)
#           )
#           (2): Conv2d(192, 32, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (3): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#       )
#       (7): InvertedResidual(
#         (conv): Sequential(
#           (0): ConvBNReLU(
#             (0): Conv2d(32, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): ReLU6(inplace=True)
#           )
#           (1): ConvBNReLU(
#             (0): Conv2d(192, 192, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), groups=192, bias=False)
#             (1): BatchNorm2d(192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): ReLU6(inplace=True)
#           )
#           (2): Conv2d(192, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (3): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#       )
#       (8): InvertedResidual(
#         (conv): Sequential(
#           (0): ConvBNReLU(
#             (0): Conv2d(64, 384, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(384, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): ReLU6(inplace=True)
#           )
#           (1): ConvBNReLU(
#             (0): Conv2d(384, 384, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=384, bias=False)
#             (1): BatchNorm2d(384, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): ReLU6(inplace=True)
#           )
#           (2): Conv2d(384, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (3): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#       )
#       (9): InvertedResidual(
#         (conv): Sequential(
#           (0): ConvBNReLU(
#             (0): Conv2d(64, 384, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(384, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): ReLU6(inplace=True)
#           )
#           (1): ConvBNReLU(
#             (0): Conv2d(384, 384, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=384, bias=False)
#             (1): BatchNorm2d(384, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): ReLU6(inplace=True)
#           )
#           (2): Conv2d(384, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (3): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#       )
#       (10): InvertedResidual(
#         (conv): Sequential(
#           (0): ConvBNReLU(
#             (0): Conv2d(64, 384, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(384, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): ReLU6(inplace=True)
#           )
#           (1): ConvBNReLU(
#             (0): Conv2d(384, 384, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=384, bias=False)
#             (1): BatchNorm2d(384, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): ReLU6(inplace=True)
#           )
#           (2): Conv2d(384, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (3): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#       )
#       (11): InvertedResidual(
#         (conv): Sequential(
#           (0): ConvBNReLU(
#             (0): Conv2d(64, 384, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(384, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): ReLU6(inplace=True)
#           )
#           (1): ConvBNReLU(
#             (0): Conv2d(384, 384, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=384, bias=False)
#             (1): BatchNorm2d(384, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): ReLU6(inplace=True)
#           )
#           (2): Conv2d(384, 96, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (3): BatchNorm2d(96, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#       )
#       (12): InvertedResidual(
#         (conv): Sequential(
#           (0): ConvBNReLU(
#             (0): Conv2d(96, 576, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(576, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): ReLU6(inplace=True)
#           )
#           (1): ConvBNReLU(
#             (0): Conv2d(576, 576, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=576, bias=False)
#             (1): BatchNorm2d(576, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): ReLU6(inplace=True)
#           )
#           (2): Conv2d(576, 96, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (3): BatchNorm2d(96, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#       )
#       (13): InvertedResidual(
#         (conv): Sequential(
#           (0): ConvBNReLU(
#             (0): Conv2d(96, 576, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(576, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): ReLU6(inplace=True)
#           )
#           (1): ConvBNReLU(
#             (0): Conv2d(576, 576, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=576, bias=False)
#             (1): BatchNorm2d(576, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): ReLU6(inplace=True)
#           )
#           (2): Conv2d(576, 96, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (3): BatchNorm2d(96, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#       )
#       (14): InvertedResidual(
#         (conv): Sequential(
#           (0): ConvBNReLU(
#             (0): Conv2d(96, 576, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(576, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): ReLU6(inplace=True)
#           )
#           (1): ConvBNReLU(
#             (0): Conv2d(576, 576, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), groups=576, bias=False)
#             (1): BatchNorm2d(576, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): ReLU6(inplace=True)
#           )
#           (2): Conv2d(576, 160, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (3): BatchNorm2d(160, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#       )
#       (15): InvertedResidual(
#         (conv): Sequential(
#           (0): ConvBNReLU(
#             (0): Conv2d(160, 960, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(960, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): ReLU6(inplace=True)
#           )
#           (1): ConvBNReLU(
#             (0): Conv2d(960, 960, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=960, bias=False)
#             (1): BatchNorm2d(960, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): ReLU6(inplace=True)
#           )
#           (2): Conv2d(960, 160, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (3): BatchNorm2d(160, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#       )
#       (16): InvertedResidual(
#         (conv): Sequential(
#           (0): ConvBNReLU(
#             (0): Conv2d(160, 960, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(960, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): ReLU6(inplace=True)
#           )
#           (1): ConvBNReLU(
#             (0): Conv2d(960, 960, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=960, bias=False)
#             (1): BatchNorm2d(960, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): ReLU6(inplace=True)
#           )
#           (2): Conv2d(960, 160, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (3): BatchNorm2d(160, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#       )
#       (17): InvertedResidual(
#         (conv): Sequential(
#           (0): ConvBNReLU(
#             (0): Conv2d(160, 960, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(960, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): ReLU6(inplace=True)
#           )
#           (1): ConvBNReLU(
#             (0): Conv2d(960, 960, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=960, bias=False)
#             (1): BatchNorm2d(960, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): ReLU6(inplace=True)
#           )
#           (2): Conv2d(960, 320, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (3): BatchNorm2d(320, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#       )
#       (18): ConvBNReLU(
#         (0): Conv2d(320, 1280, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (1): BatchNorm2d(1280, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (2): ReLU6(inplace=True)
#       )
#     )
#     (classifier): Sequential(
#       (0): Dropout(p=0.2, inplace=False)
#       (1): Sequential(
#         (0): Linear(in_features=1280, out_features=1280, bias=True)
#         (1): ReLU()
#         (2): Linear(in_features=1280, out_features=128, bias=True)
#       )
#     )
#   )
# )

# %%
#Relplace the fc layer with 10 classes instead of 128

model.backbone.classifier[1][2] = torch.nn.Linear(1280,10)

# log = model.load_state_dict(state_dict, strict=False)
# assert log.missing_keys == ['fc.weight', 'fc.bias']

# %%
train_loader, test_loader = get_stl10_data_loaders(download=True)
# print("Dataset:", config.dataset_name)
# Out:
# Files already downloaded and verified
# Files already downloaded and verified

# %%
# freeze all layers but the last fc
for name, param in model.named_parameters():
#     print(name)
    if name not in ['backbone.classifier.1.2.weight', 'backbone.classifier.1.2.bias']:
        param.requires_grad = False
    

parameters = list(filter(lambda p: p.requires_grad, model.parameters()))
assert len(parameters) == 2  # fc.weight, fc.bias

# %%
# Double check that only head is Trainable
model.to(device);
for name, param in model.named_parameters():
    if param.requires_grad != False:
        print(name)
# Out:
# backbone.classifier.1.2.weight
# backbone.classifier.1.2.bias

# %%
optimizer = torch.optim.Adam(model.parameters(), lr=3e-4, weight_decay=0.0008)
criterion = torch.nn.CrossEntropyLoss().to(device)

# %%
def accuracy(output, target, topk=(1,)):
    """Computes the accuracy over the k top predictions for the specified values of k"""
    with torch.no_grad():
        maxk = max(topk)
        batch_size = target.size(0)

        _, pred = output.topk(maxk, 1, True, True)
        pred = pred.t()
        correct = pred.eq(target.view(1, -1).expand_as(pred))

        res = []
        for k in topk:
            correct_k = correct[:k].reshape(-1).float().sum(0, keepdim=True)
            res.append(correct_k.mul_(100.0 / batch_size))
        return res

# %%
epochs = 100
for epoch in range(epochs):
  top1_train_accuracy = 0
  for counter, (x_batch, y_batch) in enumerate(train_loader):
    x_batch = x_batch.to(device)
    y_batch = y_batch.to(device)

    logits = model(x_batch)
    loss = criterion(logits, y_batch)
    top1 = accuracy(logits, y_batch, topk=(1,))
    top1_train_accuracy += top1[0]

    optimizer.zero_grad()
    loss.backward()
    optimizer.step()

  top1_train_accuracy /= (counter + 1)
  top1_accuracy = 0
  top5_accuracy = 0
  for counter, (x_batch, y_batch) in enumerate(test_loader):
    x_batch = x_batch.to(device)
    y_batch = y_batch.to(device)

    logits = model(x_batch)
  
    top1, top5 = accuracy(logits, y_batch, topk=(1,5))
    top1_accuracy += top1[0]
    top5_accuracy += top5[0]
  
  top1_accuracy /= (counter + 1)
  top5_accuracy /= (counter + 1)
  print(f"Epoch {epoch}\tTop1 Train accuracy {top1_train_accuracy.item()}\tTop1 Test accuracy: {top1_accuracy.item()}\tTop5 test acc: {top5_accuracy.item()}")
# Out:
# Epoch 0	Top1 Train accuracy 17.1875	Top1 Test accuracy: 29.6142578125	Top5 test acc: 81.64794921875
# Epoch 1	Top1 Train accuracy 38.45588302612305	Top1 Test accuracy: 46.10595703125	Top5 test acc: 92.451171875
# Epoch 2	Top1 Train accuracy 49.267005920410156	Top1 Test accuracy: 52.5927734375	Top5 test acc: 94.6142578125
# Epoch 3	Top1 Train accuracy 53.31112289428711	Top1 Test accuracy: 54.716796875	Top5 test acc: 95.28564453125
# Epoch 4	Top1 Train accuracy 55.35271072387695	Top1 Test accuracy: 55.6396484375	Top5 test acc: 95.56640625
# Epoch 5	Top1 Train accuracy 56.03400802612305	Top1 Test accuracy: 56.04736328125	Top5 test acc: 95.64697265625
# Epoch 6	Top1 Train accuracy 56.89338302612305	Top1 Test accuracy: 56.84814453125	Top5 test acc: 95.75439453125
# Epoch 7	Top1 Train accuracy 56.9611701965332	Top1 Test accuracy: 57.2802734375	Top5 test acc: 95.8447265625
# Epoch 8	Top1 Train accuracy 57.5080451965332	Top1 Test accuracy: 57.56591796875	Top5 test acc: 95.98876953125
# Epoch 9	Top1 Train accuracy 58.0353889465332	Top1 Test accuracy: 57.646484375	Top5 test acc: 96.08642578125
# Epoch 10	Top1 Train accuracy 58.02849197387695	Top1 Test accuracy: 57.71240234375	Top5 test acc: 96.1669921875
# Epoch 11	Top1 Train accuracy 58.4260139465332	Top1 Test accuracy: 57.96142578125	Top5 test acc: 96.06689453125
# Epoch 12	Top1 Train accuracy 58.336395263671875	Top1 Test accuracy: 58.09326171875	Top5 test acc: 96.1767578125
# Epoch 13	Top1 Train accuracy 58.470821380615234	Top1 Test accuracy: 58.0712890625	Top5 test acc: 96.11328125
# Epoch 14	Top1 Train accuracy 58.72932052612305	Top1 Test accuracy: 58.3837890625	Top5 test acc: 96.2353515625
# Epoch 15	Top1 Train accuracy 58.77067947387695	Top1 Test accuracy: 58.26904296875	Top5 test acc: 96.35986328125
# Epoch 16	Top1 Train accuracy 59.310665130615234	Top1 Test accuracy: 58.51318359375	Top5 test acc: 96.3720703125
# Epoch 17	Top1 Train accuracy 59.27619552612305	Top1 Test accuracy: 58.53759765625	Top5 test acc: 96.34033203125
# Epoch 18	Top1 Train accuracy 58.82927322387695	Top1 Test accuracy: 58.369140625	Top5 test acc: 96.46240234375
# Epoch 19	Top1 Train accuracy 59.31525802612305	Top1 Test accuracy: 58.6181640625	Top5 test acc: 96.3916015625
# Epoch 20	Top1 Train accuracy 59.21989822387695	Top1 Test accuracy: 58.59130859375	Top5 test acc: 96.5625
# Epoch 21	Top1 Train accuracy 59.18083572387695	Top1 Test accuracy: 58.4619140625	Top5 test acc: 96.60400390625
# Epoch 22	Top1 Train accuracy 59.41980743408203	Top1 Test accuracy: 58.60107421875	Top5 test acc: 96.56982421875
# Epoch 23	Top1 Train accuracy 59.29802322387695	Top1 Test accuracy: 58.8427734375	Top5 test acc: 96.6796875
# Epoch 24	Top1 Train accuracy 59.310665130615234	Top1 Test accuracy: 58.6181640625	Top5 test acc: 96.67236328125
# Epoch 25	Top1 Train accuracy 59.437042236328125	Top1 Test accuracy: 58.71826171875	Top5 test acc: 96.77734375
# Epoch 26	Top1 Train accuracy 59.14636993408203	Top1 Test accuracy: 58.89892578125	Top5 test acc: 96.66259765625
# Epoch 27	Top1 Train accuracy 59.391082763671875	Top1 Test accuracy: 59.03076171875	Top5 test acc: 96.68701171875
# Epoch 28	Top1 Train accuracy 59.6013298034668	Top1 Test accuracy: 58.876953125	Top5 test acc: 96.66748046875
# Epoch 29	Top1 Train accuracy 59.820770263671875	Top1 Test accuracy: 58.974609375	Top5 test acc: 96.70166015625
# Epoch 30	Top1 Train accuracy 59.96668243408203	Top1 Test accuracy: 59.07958984375	Top5 test acc: 96.66748046875
# Epoch 31	Top1 Train accuracy 59.64958572387695	Top1 Test accuracy: 59.04541015625	Top5 test acc: 96.81396484375
# Epoch 32	Top1 Train accuracy 60.11833572387695	Top1 Test accuracy: 59.03564453125	Top5 test acc: 96.84814453125
# Epoch 33	Top1 Train accuracy 59.66682052612305	Top1 Test accuracy: 59.2724609375	Top5 test acc: 96.845703125
# Epoch 34	Top1 Train accuracy 59.515167236328125	Top1 Test accuracy: 59.15771484375	Top5 test acc: 96.80908203125
# Epoch 35	Top1 Train accuracy 60.37224197387695	Top1 Test accuracy: 59.2333984375	Top5 test acc: 96.62353515625
# Epoch 36	Top1 Train accuracy 59.996551513671875	Top1 Test accuracy: 59.08447265625	Top5 test acc: 96.7529296875
# Epoch 37	Top1 Train accuracy 60.06433868408203	Top1 Test accuracy: 58.9208984375	Top5 test acc: 96.85791015625
# Epoch 38	Top1 Train accuracy 60.081573486328125	Top1 Test accuracy: 59.03564453125	Top5 test acc: 96.80419921875
# Epoch 39	Top1 Train accuracy 59.877071380615234	Top1 Test accuracy: 59.24072265625	Top5 test acc: 96.92626953125
# Epoch 40	Top1 Train accuracy 60.250457763671875	Top1 Test accuracy: 59.091796875	Top5 test acc: 96.8359375
# Epoch 41	Top1 Train accuracy 59.944854736328125	Top1 Test accuracy: 59.00634765625	Top5 test acc: 97.01416015625
# Epoch 42	Top1 Train accuracy 60.11833572387695	Top1 Test accuracy: 59.44091796875	Top5 test acc: 96.94091796875
# Epoch 43	Top1 Train accuracy 59.977020263671875	Top1 Test accuracy: 59.27490234375	Top5 test acc: 96.845703125
# Epoch 44	Top1 Train accuracy 60.01838302612305	Top1 Test accuracy: 59.3505859375	Top5 test acc: 96.7578125
# Epoch 45	Top1 Train accuracy 60.289520263671875	Top1 Test accuracy: 59.47021484375	Top5 test acc: 97.06298828125
# Epoch 46	Top1 Train accuracy 60.17692947387695	Top1 Test accuracy: 59.296875	Top5 test acc: 97.0068359375
# Epoch 47	Top1 Train accuracy 60.35041427612305	Top1 Test accuracy: 59.04541015625	Top5 test acc: 96.99951171875
# Epoch 48	Top1 Train accuracy 60.569854736328125	Top1 Test accuracy: 59.5166015625	Top5 test acc: 97.05078125
# Epoch 49	Top1 Train accuracy 60.33317947387695	Top1 Test accuracy: 59.34326171875	Top5 test acc: 96.9775390625
# Epoch 50	Top1 Train accuracy 60.328582763671875	Top1 Test accuracy: 59.55810546875	Top5 test acc: 96.97265625
# Epoch 51	Top1 Train accuracy 60.755977630615234	Top1 Test accuracy: 59.37255859375	Top5 test acc: 97.05078125
# Epoch 52	Top1 Train accuracy 60.634193420410156	Top1 Test accuracy: 59.28466796875	Top5 test acc: 96.9970703125
# Epoch 53	Top1 Train accuracy 60.348114013671875	Top1 Test accuracy: 59.05517578125	Top5 test acc: 97.10693359375
# Epoch 54	Top1 Train accuracy 60.269989013671875	Top1 Test accuracy: 59.35546875	Top5 test acc: 97.06298828125
# Epoch 55	Top1 Train accuracy 60.54572677612305	Top1 Test accuracy: 59.47998046875	Top5 test acc: 97.0458984375
# Epoch 56	Top1 Train accuracy 60.892696380615234	Top1 Test accuracy: 59.45068359375	Top5 test acc: 97.12646484375
# Epoch 57	Top1 Train accuracy 60.599727630615234	Top1 Test accuracy: 59.40185546875	Top5 test acc: 97.11669921875
# Epoch 58	Top1 Train accuracy 60.74103927612305	Top1 Test accuracy: 59.3212890625	Top5 test acc: 97.12646484375
# Epoch 59	Top1 Train accuracy 60.62385177612305	Top1 Test accuracy: 59.45068359375	Top5 test acc: 96.9775390625
# Epoch 60	Top1 Train accuracy 60.641082763671875	Top1 Test accuracy: 59.35791015625	Top5 test acc: 97.0556640625
# Epoch 61	Top1 Train accuracy 60.667510986328125	Top1 Test accuracy: 59.3505859375	Top5 test acc: 97.099609375
# Epoch 62	Top1 Train accuracy 60.66521072387695	Top1 Test accuracy: 59.53369140625	Top5 test acc: 97.08740234375
# Epoch 63	Top1 Train accuracy 61.061580657958984	Top1 Test accuracy: 59.521484375	Top5 test acc: 97.216796875
# Epoch 64	Top1 Train accuracy 60.433135986328125	Top1 Test accuracy: 59.453125	Top5 test acc: 97.236328125
# Epoch 65	Top1 Train accuracy 60.816864013671875	Top1 Test accuracy: 59.4287109375	Top5 test acc: 97.16064453125
# Epoch 66	Top1 Train accuracy 60.912227630615234	Top1 Test accuracy: 59.47509765625	Top5 test acc: 97.1435546875
# Epoch 67	Top1 Train accuracy 61.03630447387695	Top1 Test accuracy: 59.56787109375	Top5 test acc: 97.15087890625
# Epoch 68	Top1 Train accuracy 61.1833610534668	Top1 Test accuracy: 59.49951171875	Top5 test acc: 97.16064453125
# Epoch 69	Top1 Train accuracy 61.005287170410156	Top1 Test accuracy: 59.7509765625	Top5 test acc: 97.0751953125
# Epoch 70	Top1 Train accuracy 60.990352630615234	Top1 Test accuracy: 59.49462890625	Top5 test acc: 97.0166015625
# Epoch 71	Top1 Train accuracy 60.8317985534668	Top1 Test accuracy: 59.482421875	Top5 test acc: 97.24853515625
# Epoch 72	Top1 Train accuracy 60.445770263671875	Top1 Test accuracy: 59.47998046875	Top5 test acc: 97.12646484375
# Epoch 73	Top1 Train accuracy 60.621551513671875	Top1 Test accuracy: 59.58740234375	Top5 test acc: 97.24853515625
# Epoch 74	Top1 Train accuracy 60.934051513671875	Top1 Test accuracy: 59.66064453125	Top5 test acc: 97.20458984375
# Epoch 75	Top1 Train accuracy 60.924861907958984	Top1 Test accuracy: 59.66064453125	Top5 test acc: 97.13623046875
# Epoch 76	Top1 Train accuracy 61.1638298034668	Top1 Test accuracy: 59.794921875	Top5 test acc: 97.30224609375
# Epoch 77	Top1 Train accuracy 60.892696380615234	Top1 Test accuracy: 59.32861328125	Top5 test acc: 97.08740234375
# Epoch 78	Top1 Train accuracy 60.992645263671875	Top1 Test accuracy: 59.58251953125	Top5 test acc: 97.1435546875
# Epoch 79	Top1 Train accuracy 60.5974235534668	Top1 Test accuracy: 59.69482421875	Top5 test acc: 97.3046875
# Epoch 80	Top1 Train accuracy 61.239662170410156	Top1 Test accuracy: 60.01220703125	Top5 test acc: 97.18505859375
# Epoch 81	Top1 Train accuracy 61.031707763671875	Top1 Test accuracy: 59.47998046875	Top5 test acc: 97.24853515625
# Epoch 82	Top1 Train accuracy 60.951290130615234	Top1 Test accuracy: 59.6142578125	Top5 test acc: 97.255859375
# Epoch 83	Top1 Train accuracy 60.894989013671875	Top1 Test accuracy: 59.76318359375	Top5 test acc: 97.24609375
# Epoch 84	Top1 Train accuracy 61.109832763671875	Top1 Test accuracy: 59.765625	Top5 test acc: 97.35107421875
# Epoch 85	Top1 Train accuracy 61.05353927612305	Top1 Test accuracy: 59.86328125	Top5 test acc: 97.31689453125
# Epoch 86	Top1 Train accuracy 61.2028923034668	Top1 Test accuracy: 59.75830078125	Top5 test acc: 97.33642578125
# Epoch 87	Top1 Train accuracy 61.491268157958984	Top1 Test accuracy: 59.8583984375	Top5 test acc: 97.1337890625
# Epoch 88	Top1 Train accuracy 60.836395263671875	Top1 Test accuracy: 59.658203125	Top5 test acc: 97.24853515625
# Epoch 89	Top1 Train accuracy 61.063880920410156	Top1 Test accuracy: 60.00244140625	Top5 test acc: 97.32666015625
# Epoch 90	Top1 Train accuracy 61.283321380615234	Top1 Test accuracy: 59.42626953125	Top5 test acc: 97.3095703125
# Epoch 91	Top1 Train accuracy 61.029415130615234	Top1 Test accuracy: 59.98046875	Top5 test acc: 97.353515625
# Epoch 92	Top1 Train accuracy 61.1247673034668	Top1 Test accuracy: 59.9169921875	Top5 test acc: 97.3876953125
# Epoch 93	Top1 Train accuracy 61.161537170410156	Top1 Test accuracy: 59.482421875	Top5 test acc: 97.35107421875
# Epoch 94	Top1 Train accuracy 61.127071380615234	Top1 Test accuracy: 59.599609375	Top5 test acc: 97.275390625
# Epoch 95	Top1 Train accuracy 61.4372673034668	Top1 Test accuracy: 59.794921875	Top5 test acc: 97.37060546875
# Epoch 96	Top1 Train accuracy 60.970821380615234	Top1 Test accuracy: 59.833984375	Top5 test acc: 97.30224609375
# Epoch 97	Top1 Train accuracy 61.315486907958984	Top1 Test accuracy: 59.92431640625	Top5 test acc: 97.39501953125
# Epoch 98	Top1 Train accuracy 60.992645263671875	Top1 Test accuracy: 59.9755859375	Top5 test acc: 97.3828125
# Epoch 99	Top1 Train accuracy 61.19255447387695	Top1 Test accuracy: 60.01953125	Top5 test acc: 97.2607421875
